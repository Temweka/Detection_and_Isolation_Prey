# %% [markdown]
# # Building a YOLOv3 Object Detection Model with Darknet

# %% [markdown]
# Build a custom YOLOv3 object detector with a dataset that includes open source images.

# %% [markdown]
# #Cloning and Building Darknet
# Clone darknet from AlexeyAB's repository, adjust the Makefile to enable OPENCV and GPU for darknet and then build darknet.

# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 14662 (delta 0), reused 2 (delta 0), pack-reused 14658
# Receiving objects: 100% (14662/14662), 13.25 MiB | 25.04 MiB/s, done.
# Resolving deltas: 100% (9979/9979), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# make darknet (build)
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# define helper functions
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
# !pwd
# Out:
# /content/darknet

# %% [markdown]
# Connecting google drive in order to access files.

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /content
# Mounted at /content/gdrive

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
#  Assessment_Loan_Repayment.ipynb
# 'Black Literature Compendium.gdoc'
#  Check_file_valid1.csv
#  clip_results.csv
# 'Colab Notebooks'
#  Competitions
# 'Data Visualization Report Draft 2.gdoc'
#  Documents
# 'Drakensberg 2020.gform'
#  Drakensburg_accommodation.gsheet
#  events.out.tfevents.1603152556.1bd35a056d27.105.14274.v2
#  Finances
#  gciniwe-final-thesis.pdf
# 'Grocery list (1).gdoc'
# 'Grocery list.gdoc'
#  Hackathon
#  Health
#  Hyperparameter_tuning
#  Image_classification
#  images
#  Isolation_and_Detection_Prey
# 'Job Application'
#  listfile1.txt
#  listfile.txt
# 'local jupyter notebooks'
#  Megadetector
# 'MSc_AlexConway (final).pdf'
# 'My Drive'
#  Other
#  output_file.json
# 'Resnet Transfer Layer Practice.ipynb'
#  Results.RData
# 'Temweka CV'
# 'Thesis Articles'
# 'Thesis Data'
#  UmojaHack
#  useR2020-tutorial-workflowr.gslides
#  weights2.csv
# 'weights3 (1).csv'
#  weights3.csv
#  weights4.csv
#  yolo_5layerCapture.JPG
#  yolov3
#  yolov3.cfg

# %% [markdown]
# # Training Custom YOLOv3 Object Detector

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# checking folder where zip files are stored
# !ls /mydrive/yolov3/data/
# Out:
# classes.txt	   obj.data		    test.zip
# generate.py	   obj_layers5.data	    train_withopensource.zip
# generate_test.py   obj.names		    train.zip
# generate_train.py  obj_size416.data	    valid.zip
# generate_valid.py  obj_size608.data	    with_opensource
# MOVI0006.zip	   obj_size800.data	    yolov3_5l_custom.cfg
# Note.txt	   obj_withopensource.data

# %%
# copy the .zip file into the root directory of cloud VM
# !cp /mydrive/yolov3/data/train_withopensource.zip ../train.zip

# %%
# !cp /mydrive/yolov3/data/valid.zip ../

# %%
# !cp /mydrive/yolov3/data/test.zip ../

# %%
# unzip the zip file and its contents should now be in /darknet/data/obj
# !unzip ../train.zip -d data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/train/cd6a5d4eda95122d.jpg
#   inflating: data/train/cd6a5d4eda95122d.txt
#   inflating: data/train/cd727ef3d7096f1c.jpg
#   inflating: data/train/cd727ef3d7096f1c.txt
#   inflating: data/train/cd865616a9b3a417.jpg
#   inflating: data/train/cd865616a9b3a417.txt
#   inflating: data/train/cd9722271692eb04.jpg
#   inflating: data/train/cd9722271692eb04.txt
#   inflating: data/train/cdff14bb4e8d56d8.jpg
#   inflating: data/train/cdff14bb4e8d56d8.txt
#   inflating: data/train/ce20a7dab6a8e4bc.jpg
#   inflating: data/train/ce20a7dab6a8e4bc.txt
#   inflating: data/train/ce35d1f04d5d1028.jpg
#   inflating: data/train/ce35d1f04d5d1028.txt
#   inflating: data/train/ce4c35fcab510459.jpg
#   inflating: data/train/ce4c35fcab510459.txt
#   inflating: data/train/ce4d26e14b1ab0fb.jpg
#   inflating: data/train/ce4d26e14b1ab0fb.txt
#   inflating: data/train/ce695afe1d0cce47.jpg
#   inflating: data/train/ce695afe1d0cce47.txt
# ...

# %%
# !unzip ../valid.zip -d data/
# !unzip ../test.zip -d data/
# Out:
# Archive:  ../valid.zip
#   inflating: data/valid/GI-LP0237_11_MOVI0010.avi_image_2016-10-18_10_11_28_4891.png
#   inflating: data/valid/GI-LP0237_11_MOVI0010.avi_image_2016-10-18_10_11_28_4891.txt
#   inflating: data/valid/GI-LP0237_11_MOVI0010.avi_image_2016-10-18_10_11_28_4892.png
#   inflating: data/valid/GI-LP0237_11_MOVI0010.avi_image_2016-10-18_10_11_28_4892.txt
#   inflating: data/valid/GI-LP0237_11_MOVI0010.avi_image_2016-10-18_10_11_28_4893.png
#   inflating: data/valid/GI-LP0237_11_MOVI0010.avi_image_2016-10-18_10_11_28_4893.txt
#   inflating: data/valid/GI-LP0237_11_MOVI0010.avi_image_2016-10-18_10_11_28_4894.png
#   inflating: data/valid/GI-LP0237_11_MOVI0010.avi_image_2016-10-18_10_11_28_4894.txt
#   inflating: data/valid/GI-LP0237_11_MOVI0010.avi_image_2016-10-18_10_11_28_4895.png
#   inflating: data/valid/GI-LP0237_11_MOVI0010.avi_image_2016-10-18_10_11_28_4895.txt
#   inflating: data/valid/GI-LP0237_11_MOVI0010.avi_image_2016-10-18_10_11_28_4899.png
# ...

# %%
# upload the custom .cfg back to cloud VM from Google Drive
# !cp /mydrive/yolov3/learning_rate/lr0_01/yolov3_lr0_01.cfg ./cfg

# %%
# !pwd
# Out:
# /content/darknet

# %%
# upload the obj.names and obj.data files to cloud VM from Google Drive
# !cp /mydrive/yolov3/data/obj.names ./data
# !cp /mydrive/yolov3/data/obj_withopensource.data  ./data/obj.data

# %% [markdown]
# Generating train.txt, valid.txt and test.txt files which hold the relative paths to images.

# %%
# !cp /mydrive/yolov3/data/generate_train.py ./

# %%
# !cp /mydrive/yolov3/data/generate_valid.py ./

# %%
# !cp /mydrive/yolov3/data/generate_test.py ./

# %%
# !python generate_train.py

# %%
# !python generate_valid.py

# %%
# !python generate_test.py

# %%
# verify train.txt and test.txt can be seen in our darknet/data folder
# !ls data
# Out:
# 9k.tree     giraffe.jpg		      labels		scream.jpg  valid
# coco9k.map  goal.txt		      obj.data		test	    valid.txt
# coco.names  horses.jpg		      obj.names		test.txt    voc.names
# dog.jpg     imagenet.labels.list      openimages.names	train
# eagle.jpg   imagenet.shortnames.list  person.jpg	train.txt

# %%
# upload pretrained convolutional layer weights
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-01-07 14:04:09--  http://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://pjreddie.com/media/files/darknet53.conv.74 [following]
# --2021-01-07 14:04:10--  https://pjreddie.com/media/files/darknet53.conv.74
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M   387KB/s    in 6m 40s
#
# 2021-01-07 14:10:50 (397 KB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# train your custom detector
# !./darknet detector train data/obj.data cfg/yolov3_lr0_01.cfg darknet53.conv.74 -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.005656, iou_loss = 0.000000, total_loss = 0.005656
#  total_bbox = 518102, rewritten_bbox = 0.247249 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.848966), count: 3, class_loss = 0.002975, iou_loss = 0.051535, total_loss = 0.054510
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.886889), count: 2, class_loss = 0.276234, iou_loss = 0.026430, total_loss = 0.302664
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.727947), count: 2, class_loss = 0.465735, iou_loss = 0.162354, total_loss = 0.628089
#  total_bbox = 518109, rewritten_bbox = 0.247245 %
#
#  (next mAP calculation at 3964 iterations)
#  Last accuracy mAP@0.5 = 56.72 %, best = 57.20 %
# ...

# %% [markdown]
# You can observe a chart of how your model did throughout the training process by running the below command. It shows a chart of your average loss vs. iterations.

# %%
imShow('chart.png')

# %%
# !cp chart.png /mydrive/yolov3/withopensource_chart.png

# %% [markdown]
# In the event that the learning is interrupted, the process can be continued using "last.weights" from the backup folder.

# %%
# !./darknet detector train data/obj.data cfg/yolov3_lr0_01.cfg /mydrive/yolov3/with_opensource/backup/yolov3_lr0_01_last.weights -dont_show -map
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  Prepare additional network for mAP calculation...
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %% [markdown]
# # Step 6: Test Custom YOLOv3 Object Detector

# %%
# need to set our custom cfg to test mode 
# %cd cfg
# !sed -i 's/batch=64/batch=1/' yolov3_lr0_01.cfg
# !sed -i 's/subdivisions=16/subdivisions=1/' yolov3_lr0_01.cfg
# %cd ..
# Out:
# /content/darknet/cfg
# /content/darknet

# %%
# run your custom detector with this command (upload an image to your google drive to test, thresh flag sets accuracy that detection must be in order to show it)
# !./darknet detector test data/obj.data cfg/yolov3_lr0_01.cfg /mydrive/yolov3/with_opensource/backup/yolov3_lr0_01_best.weights /mydrive/images/GI-LP0268_11_MOVI0010.avi_image_2016-11-23_10_00_29_56.png -thresh 0.25
imShow('predictions.jpg')
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# !./darknet detector map data/obj.data cfg/yolov3_lr0_01.cfg /mydrive/yolov3/with_opensource/backup/yolov3_lr0_01_best.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# run your custom detector with this command (upload an image to your google drive to test, thresh flag sets accuracy that detection must be in order to show it)
# !./darknet detector test data/obj.data cfg/yolov3_lr0_01.cfg /mydrive/yolov3/with_opensource/backup/yolov3_lr0_01_best.weights -dont_show -ext_output -map < data/train.txt> result.txt
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
# ...

# %%
#save results to drive
# !cp ./result.txt /mydrive/yolov3/with_opensource/result_with_opensource_train.txt
